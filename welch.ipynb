# %%
import os 
import mne
from tqdm import tqdm
from pipe import EEGDataset
from pipe import ML_EEG
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
mne.set_log_level('ERROR')

root = "/mnt/w/Dementia_Project/Datasets/ds004504/"
dataset = EEGDataset(root,  epoch_length=38.0, overlap=19.0)
# Out:
# 100%|██████████| 88/88 [00:15<00:00,  5.80it/s]

# %% [markdown]
# # Alzheimer and Common

# %%
XX_train_data = dataset.experiments.train.ad_cn.data
yy_train = dataset.experiments.train.ad_cn.label
dataset.experiments.train.ad_cn.get_distribution()

XX_train = []

for epoch in XX_train_data:
    XX_train.append(epoch.getmne_welch())
    
XX_test_data = dataset.experiments.test.ad_cn.data
yy_test = dataset.experiments.test.ad_cn.label
dataset.experiments.test.ad_cn.get_distribution()

XX_test = []

for epoch in XX_test_data:
    XX_test.append(epoch.getmne_welch(index=0))


lda = LinearDiscriminantAnalysis()
ML_EEG(lda, XX_train, yy_train, XX_test, yy_test, label="LDA")

print("################################################")

svc = SVC(kernel='poly')
ML_EEG(svc, XX_train, yy_train, XX_test, yy_test, label="Support Vector Machine")

print("################################################")
knn =  KNeighborsClassifier(n_neighbors=13)
ML_EEG(knn, XX_train, yy_train, XX_test, yy_test, label="KNeighborsClassifier")

print("################################################")

rf = RandomForestClassifier(n_estimators=3)  
ML_EEG(rf, XX_train, yy_train, XX_test, yy_test, label="RandomForestClassifier")
# Out:
# A --> 1044 :--> 54.52%
# C --> 871 :--> 45.48%
# A --> 448 :--> 54.57%
# C --> 373 :--> 45.43%
# LDA
# Average Model Accuracy: 73.22%
# Average Sensitivity/Recall: 0.72
# Average Specificity: 0.23
# Average Precision: 0.74
# Average F1 Score: 0.72
# & 72.1 & 22.8 & 74.1 & 72.2 & 73.2
# ################################################
# Support Vector Machine
# Average Model Accuracy: 58.43%
# Average Sensitivity/Recall: 0.54
# Average Specificity: 0.45
# Average Precision: 0.73
# Average F1 Score: 0.45
# & 54.4 & 44.8 & 72.9 & 44.9 & 58.4
# ################################################
# KNeighborsClassifier
# Average Model Accuracy: 60.78%
# Average Sensitivity/Recall: 0.60
# Average Specificity: 0.29
# Average Precision: 0.60
# Average F1 Score: 0.60
# & 59.8 & 29.2 & 60.3 & 59.7 & 60.8
# ################################################
# RandomForestClassifier
# Average Model Accuracy: 54.52%
# Average Sensitivity/Recall: 0.50
# Average Specificity: 0.50
# Average Precision: 0.27
# Average F1 Score: 0.35
# & 50.0 & 50.0 & 27.3 & 35.3 & 54.5
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Alzheimer and FTD

# %%
XX_train_data = dataset.experiments.train.ad_ftd.data
yy_train = dataset.experiments.train.ad_ftd.label
dataset.experiments.train.ad_ftd.get_distribution()

XX_train = []

for epoch in XX_train_data:
    XX_train.append(epoch.getmne_welch())
    
XX_test_data = dataset.experiments.test.ad_ftd.data
yy_test = dataset.experiments.test.ad_ftd.label
dataset.experiments.test.ad_ftd.get_distribution()

XX_test = []

for epoch in XX_test_data:
    XX_test.append(epoch.getmne_welch(index=0))


lda = LinearDiscriminantAnalysis()
ML_EEG(lda, XX_train, yy_train, XX_test, yy_test, label="LDA")

print("################################################")

svc = SVC(kernel='poly')
ML_EEG(svc, XX_train, yy_train, XX_test, yy_test, label="Support Vector Machine")

print("################################################")
knn =  KNeighborsClassifier(n_neighbors=13)
ML_EEG(knn, XX_train, yy_train, XX_test, yy_test, label="KNeighborsClassifier")

print("################################################")

rf = RandomForestClassifier(n_estimators=3)  
ML_EEG(rf, XX_train, yy_train, XX_test, yy_test, label="RandomForestClassifier")
# Out:
# A --> 1044 :--> 63.78%
# F --> 593 :--> 36.22%
# A --> 448 :--> 63.73%
# F --> 255 :--> 36.27%
# LDA
# Average Model Accuracy: 68.72%
# Average Sensitivity/Recall: 0.58
# Average Specificity: 0.39
# Average Precision: 0.72
# Average F1 Score: 0.55
# & 58.0 & 39.4 & 72.1 & 55.0 & 68.7
# ################################################
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Support Vector Machine
# Average Model Accuracy: 64.69%
# Average Sensitivity/Recall: 0.51
# Average Specificity: 0.48
# Average Precision: 0.63
# Average F1 Score: 0.42
# & 51.4 & 48.3 & 62.6 & 42.0 & 64.7
# ################################################
# KNeighborsClassifier
# Average Model Accuracy: 59.56%
# Average Sensitivity/Recall: 0.50
# Average Specificity: 0.38
# Average Precision: 0.51
# Average F1 Score: 0.48
# & 50.2 & 38.2 & 50.8 & 47.6 & 59.6
# ################################################
# RandomForestClassifier
# Average Model Accuracy: 63.78%
# Average Sensitivity/Recall: 0.50
# Average Specificity: 0.50
# Average Precision: 0.32
# Average F1 Score: 0.39
# & 50.0 & 50.0 & 31.9 & 38.9 & 63.8
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Common and FTD

# %%
XX_train_data = dataset.experiments.train.cn_ftd.data
yy_train = dataset.experiments.train.cn_ftd.label
dataset.experiments.train.cn_ftd.get_distribution()

XX_train = []

for epoch in XX_train_data:
    XX_train.append(epoch.getmne_welch())
    
XX_test_data = dataset.experiments.test.cn_ftd.data
yy_test = dataset.experiments.test.cn_ftd.label
dataset.experiments.test.cn_ftd.get_distribution()

XX_test = []

for epoch in XX_test_data:
    XX_test.append(epoch.getmne_welch(index=0))


lda = LinearDiscriminantAnalysis()
ML_EEG(lda, XX_train, yy_train, XX_test, yy_test, label="LDA")

print("################################################")

svc = SVC(kernel='poly')
ML_EEG(svc, XX_train, yy_train, XX_test, yy_test, label="Support Vector Machine")

print("################################################")
knn =  KNeighborsClassifier(n_neighbors=13)
ML_EEG(knn, XX_train, yy_train, XX_test, yy_test, label="KNeighborsClassifier")

print("################################################")

rf = RandomForestClassifier(n_estimators=3)  
ML_EEG(rf, XX_train, yy_train, XX_test, yy_test, label="RandomForestClassifier")
# Out:
# C --> 871 :--> 59.49%
# F --> 593 :--> 40.51%
# C --> 373 :--> 59.39%
# F --> 255 :--> 40.61%
# LDA
# Average Model Accuracy: 74.19%
# Average Sensitivity/Recall: 0.70
# Average Specificity: 0.26
# Average Precision: 0.76
# Average F1 Score: 0.71
# & 70.1 & 25.9 & 76.1 & 70.6 & 74.2
# ################################################
# Support Vector Machine
# Average Model Accuracy: 63.32%
# Average Sensitivity/Recall: 0.55
# Average Specificity: 0.43
# Average Precision: 0.73
# Average F1 Score: 0.49
# & 55.2 & 43.3 & 72.5 & 48.6 & 63.3
# ################################################
# KNeighborsClassifier
# Average Model Accuracy: 62.91%
# Average Sensitivity/Recall: 0.59
# Average Specificity: 0.31
# Average Precision: 0.61
# Average F1 Score: 0.58
# & 58.8 & 31.5 & 60.9 & 58.2 & 62.9
# ################################################
# RandomForestClassifier
# Average Model Accuracy: 59.49%
# Average Sensitivity/Recall: 0.50
# Average Specificity: 0.50
# Average Precision: 0.30
# Average F1 Score: 0.37
# & 50.0 & 50.0 & 29.7 & 37.3 & 59.5
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/dev28/miniconda3/envs/dem/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
